# %%
# !unzip /data.zip
# Out:
# Archive:  /data.zip
#    creating: data/
#   inflating: data/.DS_Store
#   inflating: __MACOSX/data/._.DS_Store
#    creating: data/test/
#   inflating: __MACOSX/data/._test
#    creating: data/train/
#   inflating: __MACOSX/data/._train
#   inflating: data/test/.DS_Store
#   inflating: __MACOSX/data/test/._.DS_Store
#    creating: data/test/jpg/
#   inflating: __MACOSX/data/test/._jpg
#   inflating: data/train/.DS_Store
#   inflating: __MACOSX/data/train/._.DS_Store
#    creating: data/train/jpg/
#   inflating: __MACOSX/data/train/._jpg
#   inflating: data/test/jpg/.DS_Store
#   inflating: __MACOSX/data/test/jpg/._.DS_Store
#    creating: data/test/jpg/jpg/
#   inflating: __MACOSX/data/test/jpg/._jpg
#   inflating: data/train/jpg/.DS_Store
#   inflating: __MACOSX/data/train/jpg/._.DS_Store
#    creating: data/train/jpg/jpg/
#   inflating: __MACOSX/data/train/jpg/._jpg
#   inflating: data/test/jpg/jpg/.DS_Store
#   inflating: __MACOSX/data/test/jpg/jpg/._.DS_Store
#    creating: data/test/jpg/jpg/Groud_Squirrel/
#   inflating: __MACOSX/data/test/jpg/jpg/._Groud_Squirrel
#    creating: data/test/jpg/jpg/Bald_Eagle/
#   inflating: __MACOSX/data/test/jpg/jpg/._Bald_Eagle
#    creating: data/test/jpg/jpg/Elk/
#   inflating: __MACOSX/data/test/jpg/jpg/._Elk
#    creating: data/test/jpg/jpg/Black_Bear/
#   inflating: __MACOSX/data/test/jpg/jpg/._Black_Bear
#    creating: data/test/jpg/jpg/Wolf/
#   inflating: __MACOSX/data/test/jpg/jpg/._Wolf
#    creating: data/test/jpg/jpg/River_Otter/
#   inflating: __MACOSX/data/test/jpg/jpg/._River_Otter
#    creating: data/test/jpg/jpg/Bighorn_Sheep/
#   inflating: __MACOSX/data/test/jpg/jpg/._Bighorn_Sheep
#    creating: data/test/jpg/jpg/Grizzly_Bear/
#   inflating: __MACOSX/data/test/jpg/jpg/._Grizzly_Bear
#    creating: data/test/jpg/jpg/Bull_Moose/
#   inflating: __MACOSX/data/test/jpg/jpg/._Bull_Moose
#    creating: data/test/jpg/jpg/Bison/
#   inflating: __MACOSX/data/test/jpg/jpg/._Bison
#    creating: data/test/jpg/jpg/Deer/
#   inflating: __MACOSX/data/test/jpg/jpg/._Deer
#    creating: data/test/jpg/jpg/Badger/
#   inflating: __MACOSX/data/test/jpg/jpg/._Badger
#   inflating: data/train/jpg/jpg/.DS_Store
#   inflating: __MACOSX/data/train/jpg/jpg/._.DS_Store
#    creating: data/train/jpg/jpg/Groud_Squirrel/
#   inflating: __MACOSX/data/train/jpg/jpg/._Groud_Squirrel
#    creating: data/train/jpg/jpg/Red_Fox/
#   inflating: __MACOSX/data/train/jpg/jpg/._Red_Fox
#    creating: data/train/jpg/jpg/Bald_Eagle/
#   inflating: __MACOSX/data/train/jpg/jpg/._Bald_Eagle
#    creating: data/train/jpg/jpg/Elk/
#   inflating: __MACOSX/data/train/jpg/jpg/._Elk
#    creating: data/train/jpg/jpg/Black_Bear/
#   inflating: __MACOSX/data/train/jpg/jpg/._Black_Bear
#    creating: data/train/jpg/jpg/Beaver/
#   inflating: __MACOSX/data/train/jpg/jpg/._Beaver
#    creating: data/train/jpg/jpg/Wolf/
#   inflating: __MACOSX/data/train/jpg/jpg/._Wolf
#    creating: data/train/jpg/jpg/Gastropods/
#   inflating: __MACOSX/data/train/jpg/jpg/._Gastropods
#    creating: data/train/jpg/jpg/River_Otter/
#   inflating: __MACOSX/data/train/jpg/jpg/._River_Otter
#    creating: data/train/jpg/jpg/Bighorn_Sheep/
#   inflating: __MACOSX/data/train/jpg/jpg/._Bighorn_Sheep
#    creating: data/train/jpg/jpg/Grizzly_Bear/
#   inflating: __MACOSX/data/train/jpg/jpg/._Grizzly_Bear
#    creating: data/train/jpg/jpg/Bull_Moose/
#   inflating: __MACOSX/data/train/jpg/jpg/._Bull_Moose
#    creating: data/train/jpg/jpg/Bison/
#   inflating: __MACOSX/data/train/jpg/jpg/._Bison
#    creating: data/train/jpg/jpg/Deer/
#   inflating: __MACOSX/data/train/jpg/jpg/._Deer
#    creating: data/train/jpg/jpg/Badger/
#   inflating: __MACOSX/data/train/jpg/jpg/._Badger
#   inflating: data/test/jpg/jpg/Groud_Squirrel/.DS_Store
#   inflating: __MACOSX/data/test/jpg/jpg/Groud_Squirrel/._.DS_Store
#   inflating: data/test/jpg/jpg/Groud_Squirrel/Ground_Squirrel1.jpg
#   inflating: __MACOSX/data/test/jpg/jpg/Groud_Squirrel/._Ground_Squirrel1.jpg
#   inflating: data/test/jpg/jpg/Bald_Eagle/Bald_Eagle2.jpg
#   inflating: __MACOSX/data/test/jpg/jpg/Bald_Eagle/._Bald_Eagle2.jpg
#   inflating: data/test/jpg/jpg/Bald_Eagle/Bald_Eagle7.jpg
#   inflating: __MACOSX/data/test/jpg/jpg/Bald_Eagle/._Bald_Eagle7.jpg
#   inflating: data/test/jpg/jpg/Elk/.DS_Store
#   inflating: __MACOSX/data/test/jpg/jpg/Elk/._.DS_Store
#   inflating: data/test/jpg/jpg/Elk/Elk7.jpg
#   inflating: __MACOSX/data/test/jpg/jpg/Elk/._Elk7.jpg
#   inflating: data/test/jpg/jpg/Black_Bear/Black_Bear7.jpg
#   inflating: __MACOSX/data/test/jpg/jpg/Black_Bear/._Black_Bear7.jpg
#   inflating: data/test/jpg/jpg/Black_Bear/.DS_Store
#   inflating: __MACOSX/data/test/jpg/jpg/Black_Bear/._.DS_Store
#   inflating: data/test/jpg/jpg/Wolf/Wolf5.jpg
#   inflating: __MACOSX/data/test/jpg/jpg/Wolf/._Wolf5.jpg
#   inflating: data/test/jpg/jpg/Wolf/Wolf7.jpg
#   inflating: __MACOSX/data/test/jpg/jpg/Wolf/._Wolf7.jpg
#   inflating: data/test/jpg/jpg/Wolf/.DS_Store
#   inflating: __MACOSX/data/test/jpg/jpg/Wolf/._.DS_Store
#   inflating: data/test/jpg/jpg/Wolf/Wolf1.jpg
#   inflating: __MACOSX/data/test/jpg/jpg/Wolf/._Wolf1.jpg
#   inflating: data/test/jpg/jpg/River_Otter/.DS_Store
#   inflating: __MACOSX/data/test/jpg/jpg/River_Otter/._.DS_Store
#   inflating: data/test/jpg/jpg/River_Otter/River_Otter6.jpg
#   inflating: __MACOSX/data/test/jpg/jpg/River_Otter/._River_Otter6.jpg
#   inflating: data/test/jpg/jpg/River_Otter/River_Otter3.jpg
#   inflating: __MACOSX/data/test/jpg/jpg/River_Otter/._River_Otter3.jpg
#   inflating: data/test/jpg/jpg/River_Otter/River_Otter1.jpg
#   inflating: __MACOSX/data/test/jpg/jpg/River_Otter/._River_Otter1.jpg
#   inflating: data/test/jpg/jpg/Bighorn_Sheep/.DS_Store
#   inflating: __MACOSX/data/test/jpg/jpg/Bighorn_Sheep/._.DS_Store
#   inflating: data/test/jpg/jpg/Bighorn_Sheep/Bighorn_Sheep4.jpg
#   inflating: __MACOSX/data/test/jpg/jpg/Bighorn_Sheep/._Bighorn_Sheep4.jpg
#   inflating: data/test/jpg/jpg/Bighorn_Sheep/Bighorn_Sheep3.jpg
#   inflating: __MACOSX/data/test/jpg/jpg/Bighorn_Sheep/._Bighorn_Sheep3.jpg
#   inflating: data/test/jpg/jpg/Grizzly_Bear/.DS_Store
#   inflating: __MACOSX/data/test/jpg/jpg/Grizzly_Bear/._.DS_Store
#   inflating: data/test/jpg/jpg/Grizzly_Bear/Grizzly_Bear2.jpg
#   inflating: __MACOSX/data/test/jpg/jpg/Grizzly_Bear/._Grizzly_Bear2.jpg
#   inflating: data/test/jpg/jpg/Bull_Moose/.DS_Store
#   inflating: __MACOSX/data/test/jpg/jpg/Bull_Moose/._.DS_Store
#   inflating: data/test/jpg/jpg/Bull_Moose/Bull_Moose6.jpg
#   inflating: __MACOSX/data/test/jpg/jpg/Bull_Moose/._Bull_Moose6.jpg
#   inflating: data/test/jpg/jpg/Bull_Moose/Bull_Moose5.jpg
#   inflating: __MACOSX/data/test/jpg/jpg/Bull_Moose/._Bull_Moose5.jpg
#   inflating: data/test/jpg/jpg/Bull_Moose/Bull_Moose4.jpg
#   inflating: __MACOSX/data/test/jpg/jpg/Bull_Moose/._Bull_Moose4.jpg
#   inflating: data/test/jpg/jpg/Bison/.DS_Store
#   inflating: __MACOSX/data/test/jpg/jpg/Bison/._.DS_Store
#   inflating: data/test/jpg/jpg/Bison/Bison5.jpg
#   inflating: __MACOSX/data/test/jpg/jpg/Bison/._Bison5.jpg
#   inflating: data/test/jpg/jpg/Bison/Bison7.jpg
#   inflating: __MACOSX/data/test/jpg/jpg/Bison/._Bison7.jpg
#   inflating: data/test/jpg/jpg/Deer/.DS_Store
#   inflating: __MACOSX/data/test/jpg/jpg/Deer/._.DS_Store
#   inflating: data/test/jpg/jpg/Deer/Deer2.jpg
#   inflating: __MACOSX/data/test/jpg/jpg/Deer/._Deer2.jpg
#   inflating: data/test/jpg/jpg/Badger/.DS_Store
#   inflating: __MACOSX/data/test/jpg/jpg/Badger/._.DS_Store
#   inflating: data/test/jpg/jpg/Badger/Badger6.jpg
#   inflating: __MACOSX/data/test/jpg/jpg/Badger/._Badger6.jpg
#   inflating: data/test/jpg/jpg/Badger/Badger0.jpg
#   inflating: __MACOSX/data/test/jpg/jpg/Badger/._Badger0.jpg
#   inflating: data/train/jpg/jpg/Groud_Squirrel/Ground_Squirrel2.jpg
#   inflating: __MACOSX/data/train/jpg/jpg/Groud_Squirrel/._Ground_Squirrel2.jpg
#   inflating: data/train/jpg/jpg/Groud_Squirrel/.DS_Store
#   inflating: __MACOSX/data/train/jpg/jpg/Groud_Squirrel/._.DS_Store
#   inflating: data/train/jpg/jpg/Groud_Squirrel/Ground_Squirrel0.jpg
#   inflating: __MACOSX/data/train/jpg/jpg/Groud_Squirrel/._Ground_Squirrel0.jpg
#   inflating: data/train/jpg/jpg/Red_Fox/.DS_Store
#   inflating: __MACOSX/data/train/jpg/jpg/Red_Fox/._.DS_Store
#   inflating: data/train/jpg/jpg/Red_Fox/Red_Fox3.jpg
#   inflating: __MACOSX/data/train/jpg/jpg/Red_Fox/._Red_Fox3.jpg
#   inflating: data/train/jpg/jpg/Red_Fox/Red_Fox2.jpg
#   inflating: __MACOSX/data/train/jpg/jpg/Red_Fox/._Red_Fox2.jpg
#   inflating: data/train/jpg/jpg/Red_Fox/Red_Fox0.jpg
#   inflating: __MACOSX/data/train/jpg/jpg/Red_Fox/._Red_Fox0.jpg
#   inflating: data/train/jpg/jpg/Red_Fox/Red_Fox1.jpg
#   inflating: __MACOSX/data/train/jpg/jpg/Red_Fox/._Red_Fox1.jpg
#   inflating: data/train/jpg/jpg/Red_Fox/Red_Fox5.jpg
#   inflating: __MACOSX/data/train/jpg/jpg/Red_Fox/._Red_Fox5.jpg
#   inflating: data/train/jpg/jpg/Red_Fox/Red_Fox4.jpg
#   inflating: __MACOSX/data/train/jpg/jpg/Red_Fox/._Red_Fox4.jpg
#   inflating: data/train/jpg/jpg/Red_Fox/Red_Fox6.jpg
#   inflating: __MACOSX/data/train/jpg/jpg/Red_Fox/._Red_Fox6.jpg
#   inflating: data/train/jpg/jpg/Red_Fox/Red_Fox7.jpg
#   inflating: __MACOSX/data/train/jpg/jpg/Red_Fox/._Red_Fox7.jpg
#   inflating: data/train/jpg/jpg/Bald_Eagle/.DS_Store
#   inflating: __MACOSX/data/train/jpg/jpg/Bald_Eagle/._.DS_Store
#   inflating: data/train/jpg/jpg/Bald_Eagle/Bald_Eagle3.jpg
#   inflating: __MACOSX/data/train/jpg/jpg/Bald_Eagle/._Bald_Eagle3.jpg
#   inflating: data/train/jpg/jpg/Bald_Eagle/Bald_Eagle1.jpg
#   inflating: __MACOSX/data/train/jpg/jpg/Bald_Eagle/._Bald_Eagle1.jpg
#   inflating: data/train/jpg/jpg/Bald_Eagle/Bald_Eagle0.jpg
#   inflating: __MACOSX/data/train/jpg/jpg/Bald_Eagle/._Bald_Eagle0.jpg
#   inflating: data/train/jpg/jpg/Bald_Eagle/Bald_Eagle4.jpg
#   inflating: __MACOSX/data/train/jpg/jpg/Bald_Eagle/._Bald_Eagle4.jpg
#   inflating: data/train/jpg/jpg/Bald_Eagle/Bald_Eagle5.jpg
#   inflating: __MACOSX/data/train/jpg/jpg/Bald_Eagle/._Bald_Eagle5.jpg
#   inflating: data/train/jpg/jpg/Bald_Eagle/Bald_Eagle6.jpg
#   inflating: __MACOSX/data/train/jpg/jpg/Bald_Eagle/._Bald_Eagle6.jpg
#   inflating: data/train/jpg/jpg/Elk/.DS_Store
#   inflating: __MACOSX/data/train/jpg/jpg/Elk/._.DS_Store
#   inflating: data/train/jpg/jpg/Elk/Elk5.jpg
#   inflating: __MACOSX/data/train/jpg/jpg/Elk/._Elk5.jpg
#   inflating: data/train/jpg/jpg/Elk/Elk4.jpg
#   inflating: __MACOSX/data/train/jpg/jpg/Elk/._Elk4.jpg
#   inflating: data/train/jpg/jpg/Elk/Elk6.jpg
#   inflating: __MACOSX/data/train/jpg/jpg/Elk/._Elk6.jpg
#   inflating: data/train/jpg/jpg/Elk/Elk3.jpg
#   inflating: __MACOSX/data/train/jpg/jpg/Elk/._Elk3.jpg
#   inflating: data/train/jpg/jpg/Elk/Elk2.jpg
#   inflating: __MACOSX/data/train/jpg/jpg/Elk/._Elk2.jpg
#   inflating: data/train/jpg/jpg/Elk/Elk0.jpg
#   inflating: __MACOSX/data/train/jpg/jpg/Elk/._Elk0.jpg
#   inflating: data/train/jpg/jpg/Elk/Elk1.jpg
#   inflating: __MACOSX/data/train/jpg/jpg/Elk/._Elk1.jpg
#   inflating: data/train/jpg/jpg/Black_Bear/Black_Bear4.jpg
#   inflating: __MACOSX/data/train/jpg/jpg/Black_Bear/._Black_Bear4.jpg
#   inflating: data/train/jpg/jpg/Black_Bear/Black_Bear5.jpg
#   inflating: __MACOSX/data/train/jpg/jpg/Black_Bear/._Black_Bear5.jpg
#   inflating: data/train/jpg/jpg/Black_Bear/Black_Bear6.jpg
#   inflating: __MACOSX/data/train/jpg/jpg/Black_Bear/._Black_Bear6.jpg
#   inflating: data/train/jpg/jpg/Black_Bear/.DS_Store
#   inflating: __MACOSX/data/train/jpg/jpg/Black_Bear/._.DS_Store
#   inflating: data/train/jpg/jpg/Black_Bear/Black_Bear2.jpg
#   inflating: __MACOSX/data/train/jpg/jpg/Black_Bear/._Black_Bear2.jpg
#   inflating: data/train/jpg/jpg/Black_Bear/Black_Bear3.jpg
#   inflating: __MACOSX/data/train/jpg/jpg/Black_Bear/._Black_Bear3.jpg
#   inflating: data/train/jpg/jpg/Black_Bear/Black_Bear1.jpg
#   inflating: __MACOSX/data/train/jpg/jpg/Black_Bear/._Black_Bear1.jpg
#   inflating: data/train/jpg/jpg/Black_Bear/Black_Bear0.jpg
#   inflating: __MACOSX/data/train/jpg/jpg/Black_Bear/._Black_Bear0.jpg
#   inflating: data/train/jpg/jpg/Beaver/Beaver4.jpg
#   inflating: __MACOSX/data/train/jpg/jpg/Beaver/._Beaver4.jpg
#   inflating: data/train/jpg/jpg/Beaver/Beaver5.jpg
#   inflating: __MACOSX/data/train/jpg/jpg/Beaver/._Beaver5.jpg
#   inflating: data/train/jpg/jpg/Beaver/Beaver7.jpg
#   inflating: __MACOSX/data/train/jpg/jpg/Beaver/._Beaver7.jpg
#   inflating: data/train/jpg/jpg/Beaver/Beaver6.jpg
#   inflating: __MACOSX/data/train/jpg/jpg/Beaver/._Beaver6.jpg
#   inflating: data/train/jpg/jpg/Beaver/Beaver2.jpg
#   inflating: __MACOSX/data/train/jpg/jpg/Beaver/._Beaver2.jpg
#   inflating: data/train/jpg/jpg/Beaver/.DS_Store
#   inflating: __MACOSX/data/train/jpg/jpg/Beaver/._.DS_Store
#   inflating: data/train/jpg/jpg/Beaver/Beaver3.jpg
#   inflating: __MACOSX/data/train/jpg/jpg/Beaver/._Beaver3.jpg
#   inflating: data/train/jpg/jpg/Beaver/Beaver1.jpg
#   inflating: __MACOSX/data/train/jpg/jpg/Beaver/._Beaver1.jpg
#   inflating: data/train/jpg/jpg/Beaver/Beaver0.jpg
#   inflating: __MACOSX/data/train/jpg/jpg/Beaver/._Beaver0.jpg
#   inflating: data/train/jpg/jpg/Wolf/Wolf4.jpg
#   inflating: __MACOSX/data/train/jpg/jpg/Wolf/._Wolf4.jpg
#   inflating: data/train/jpg/jpg/Wolf/Wolf6.jpg
#   inflating: __MACOSX/data/train/jpg/jpg/Wolf/._Wolf6.jpg
#   inflating: data/train/jpg/jpg/Wolf/Wolf3.jpg
#   inflating: __MACOSX/data/train/jpg/jpg/Wolf/._Wolf3.jpg
#   inflating: data/train/jpg/jpg/Wolf/.DS_Store
#   inflating: __MACOSX/data/train/jpg/jpg/Wolf/._.DS_Store
#   inflating: data/train/jpg/jpg/Wolf/Wolf2.jpg
#   inflating: __MACOSX/data/train/jpg/jpg/Wolf/._Wolf2.jpg
#   inflating: data/train/jpg/jpg/Wolf/Wolf0.jpg
#   inflating: __MACOSX/data/train/jpg/jpg/Wolf/._Wolf0.jpg
#   inflating: data/train/jpg/jpg/Gastropods/Gastropods0.jpg
#   inflating: __MACOSX/data/train/jpg/jpg/Gastropods/._Gastropods0.jpg
#   inflating: data/train/jpg/jpg/Gastropods/Gastropods1.jpg
#   inflating: __MACOSX/data/train/jpg/jpg/Gastropods/._Gastropods1.jpg
#   inflating: data/train/jpg/jpg/River_Otter/.DS_Store
#   inflating: __MACOSX/data/train/jpg/jpg/River_Otter/._.DS_Store
#   inflating: data/train/jpg/jpg/River_Otter/River_Otter5.jpg
#   inflating: __MACOSX/data/train/jpg/jpg/River_Otter/._River_Otter5.jpg
#   inflating: data/train/jpg/jpg/River_Otter/River_Otter4.jpg
#   inflating: __MACOSX/data/train/jpg/jpg/River_Otter/._River_Otter4.jpg
#   inflating: data/train/jpg/jpg/River_Otter/River_Otter7.jpg
#   inflating: __MACOSX/data/train/jpg/jpg/River_Otter/._River_Otter7.jpg
#   inflating: data/train/jpg/jpg/River_Otter/River_Otter2.jpg
#   inflating: __MACOSX/data/train/jpg/jpg/River_Otter/._River_Otter2.jpg
#   inflating: data/train/jpg/jpg/River_Otter/River_Otter0.jpg
#   inflating: __MACOSX/data/train/jpg/jpg/River_Otter/._River_Otter0.jpg
#   inflating: data/train/jpg/jpg/Bighorn_Sheep/.DS_Store
#   inflating: __MACOSX/data/train/jpg/jpg/Bighorn_Sheep/._.DS_Store
#   inflating: data/train/jpg/jpg/Bighorn_Sheep/Bighorn_Sheep5.jpg
#   inflating: __MACOSX/data/train/jpg/jpg/Bighorn_Sheep/._Bighorn_Sheep5.jpg
#   inflating: data/train/jpg/jpg/Bighorn_Sheep/Bighorn_Sheep6.jpg
#   inflating: __MACOSX/data/train/jpg/jpg/Bighorn_Sheep/._Bighorn_Sheep6.jpg
#   inflating: data/train/jpg/jpg/Bighorn_Sheep/Bighorn_Sheep7.jpg
#   inflating: __MACOSX/data/train/jpg/jpg/Bighorn_Sheep/._Bighorn_Sheep7.jpg
#   inflating: data/train/jpg/jpg/Bighorn_Sheep/Bighorn_Sheep2.jpg
#   inflating: __MACOSX/data/train/jpg/jpg/Bighorn_Sheep/._Bighorn_Sheep2.jpg
#   inflating: data/train/jpg/jpg/Bighorn_Sheep/Bighorn_Sheep0.jpg
#   inflating: __MACOSX/data/train/jpg/jpg/Bighorn_Sheep/._Bighorn_Sheep0.jpg
#   inflating: data/train/jpg/jpg/Bighorn_Sheep/Bighorn_Sheep1.jpg
#   inflating: __MACOSX/data/train/jpg/jpg/Bighorn_Sheep/._Bighorn_Sheep1.jpg
#   inflating: data/train/jpg/jpg/Grizzly_Bear/.DS_Store
#   inflating: __MACOSX/data/train/jpg/jpg/Grizzly_Bear/._.DS_Store
#   inflating: data/train/jpg/jpg/Grizzly_Bear/Grizzly_Bear7.jpg
#   inflating: __MACOSX/data/train/jpg/jpg/Grizzly_Bear/._Grizzly_Bear7.jpg
#   inflating: data/train/jpg/jpg/Grizzly_Bear/Grizzly_Bear6.jpg
#   inflating: __MACOSX/data/train/jpg/jpg/Grizzly_Bear/._Grizzly_Bear6.jpg
#   inflating: data/train/jpg/jpg/Grizzly_Bear/Grizzly_Bear4.jpg
#   inflating: __MACOSX/data/train/jpg/jpg/Grizzly_Bear/._Grizzly_Bear4.jpg
#   inflating: data/train/jpg/jpg/Grizzly_Bear/Grizzly_Bear5.jpg
#   inflating: __MACOSX/data/train/jpg/jpg/Grizzly_Bear/._Grizzly_Bear5.jpg
#   inflating: data/train/jpg/jpg/Grizzly_Bear/Grizzly_Bear1.jpg
#   inflating: __MACOSX/data/train/jpg/jpg/Grizzly_Bear/._Grizzly_Bear1.jpg
#   inflating: data/train/jpg/jpg/Grizzly_Bear/Grizzly_Bear0.jpg
#   inflating: __MACOSX/data/train/jpg/jpg/Grizzly_Bear/._Grizzly_Bear0.jpg
#   inflating: data/train/jpg/jpg/Grizzly_Bear/Grizzly_Bear3.jpg
#   inflating: __MACOSX/data/train/jpg/jpg/Grizzly_Bear/._Grizzly_Bear3.jpg
#   inflating: data/train/jpg/jpg/Bull_Moose/.DS_Store
#   inflating: __MACOSX/data/train/jpg/jpg/Bull_Moose/._.DS_Store
#   inflating: data/train/jpg/jpg/Bull_Moose/Bull_Moose0.jpg
#   inflating: __MACOSX/data/train/jpg/jpg/Bull_Moose/._Bull_Moose0.jpg
#   inflating: data/train/jpg/jpg/Bull_Moose/Bull_Moose1.jpg
#   inflating: __MACOSX/data/train/jpg/jpg/Bull_Moose/._Bull_Moose1.jpg
#   inflating: data/train/jpg/jpg/Bull_Moose/Bull_Moose3.jpg
#   inflating: __MACOSX/data/train/jpg/jpg/Bull_Moose/._Bull_Moose3.jpg
#   inflating: data/train/jpg/jpg/Bull_Moose/Bull_Moose2.jpg
#   inflating: __MACOSX/data/train/jpg/jpg/Bull_Moose/._Bull_Moose2.jpg
#   inflating: data/train/jpg/jpg/Bison/.DS_Store
#   inflating: __MACOSX/data/train/jpg/jpg/Bison/._.DS_Store
#   inflating: data/train/jpg/jpg/Bison/Bison2.jpg
#   inflating: __MACOSX/data/train/jpg/jpg/Bison/._Bison2.jpg
#   inflating: data/train/jpg/jpg/Bison/Bison3.jpg
#   inflating: __MACOSX/data/train/jpg/jpg/Bison/._Bison3.jpg
#   inflating: data/train/jpg/jpg/Bison/Bison1.jpg
#   inflating: __MACOSX/data/train/jpg/jpg/Bison/._Bison1.jpg
#   inflating: data/train/jpg/jpg/Bison/Bison0.jpg
#   inflating: __MACOSX/data/train/jpg/jpg/Bison/._Bison0.jpg
#   inflating: data/train/jpg/jpg/Bison/Bison4.jpg
#   inflating: __MACOSX/data/train/jpg/jpg/Bison/._Bison4.jpg
#   inflating: data/train/jpg/jpg/Bison/Bison6.jpg
#   inflating: __MACOSX/data/train/jpg/jpg/Bison/._Bison6.jpg
#   inflating: data/train/jpg/jpg/Deer/.DS_Store
#   inflating: __MACOSX/data/train/jpg/jpg/Deer/._.DS_Store
#   inflating: data/train/jpg/jpg/Deer/Deer6.jpg
#   inflating: __MACOSX/data/train/jpg/jpg/Deer/._Deer6.jpg
#   inflating: data/train/jpg/jpg/Deer/Deer7.jpg
#   inflating: __MACOSX/data/train/jpg/jpg/Deer/._Deer7.jpg
#   inflating: data/train/jpg/jpg/Deer/Deer5.jpg
#   inflating: __MACOSX/data/train/jpg/jpg/Deer/._Deer5.jpg
#   inflating: data/train/jpg/jpg/Deer/Deer4.jpg
#   inflating: __MACOSX/data/train/jpg/jpg/Deer/._Deer4.jpg
#   inflating: data/train/jpg/jpg/Deer/Deer0.jpg
#   inflating: __MACOSX/data/train/jpg/jpg/Deer/._Deer0.jpg
#   inflating: data/train/jpg/jpg/Deer/Deer1.jpg
#   inflating: __MACOSX/data/train/jpg/jpg/Deer/._Deer1.jpg
#   inflating: data/train/jpg/jpg/Deer/Deer3.jpg
#   inflating: __MACOSX/data/train/jpg/jpg/Deer/._Deer3.jpg
#   inflating: data/train/jpg/jpg/Badger/.DS_Store
#   inflating: __MACOSX/data/train/jpg/jpg/Badger/._.DS_Store
#   inflating: data/train/jpg/jpg/Badger/Badger7.jpg
#   inflating: __MACOSX/data/train/jpg/jpg/Badger/._Badger7.jpg
#   inflating: data/train/jpg/jpg/Badger/Badger4.jpg
#   inflating: __MACOSX/data/train/jpg/jpg/Badger/._Badger4.jpg
#   inflating: data/train/jpg/jpg/Badger/Badger5.jpg
#   inflating: __MACOSX/data/train/jpg/jpg/Badger/._Badger5.jpg
#   inflating: data/train/jpg/jpg/Badger/Badger1.jpg
#   inflating: __MACOSX/data/train/jpg/jpg/Badger/._Badger1.jpg
#   inflating: data/train/jpg/jpg/Badger/Badger2.jpg
#   inflating: __MACOSX/data/train/jpg/jpg/Badger/._Badger2.jpg
#   inflating: data/train/jpg/jpg/Badger/Badger3.jpg
#   inflating: __MACOSX/data/train/jpg/jpg/Badger/._Badger3.jpg

# %%
# !pip install torch
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.optim.lr_scheduler import _LRScheduler
import torch.utils.data as data
import torchvision
import torchvision.transforms as transforms
import torchvision.datasets as datasets
from torchvision import models

from sklearn import decomposition
from sklearn import manifold
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
from tqdm.notebook import tqdm, trange
import matplotlib.pyplot as plt
import numpy as np

import copy
import random
import time
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (1.12.0+cu113)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch) (4.1.1)

# %%
# ## Create train and test folders 
train_path = "/content/data/train/"

test_path = "/content/data/test/"

# %%
## Define the function to transform images / conduct bootstrapping 
class SquarePad:
    def __call__(self, image):
        max_wh = max(image.size)
        p_left, p_top = [(max_wh - s) // 2 for s in image.size]
        p_right, p_bottom = [max_wh - (s+pad) for s, pad in zip(image.size, [p_left, p_top])]
        padding = (p_left, p_top, p_right, p_bottom)
        return torchvision.transforms.functional.pad(image, padding, 0, 'constant')

mean = [0.5683, 0.5578, 0.5178]
std = [0.2378, 0.2437, 0.2670]

transform = torchvision.transforms.Compose(
    [
      SquarePad(),
      torchvision.transforms.RandomHorizontalFlip(p = 0.5),
      torchvision.transforms.RandomVerticalFlip(p = 0.5),
      torchvision.transforms.Resize(224),
      torchvision.transforms.ToTensor(),
      torchvision.transforms.Normalize(
          mean=mean,
          std=std
          )
    ]
)

train = torchvision.datasets.ImageFolder(
    root = train_path+'jpg/jpg/',
    transform = transform
)


train_loader = torch.utils.data.DataLoader(
    train, 
    batch_size= 32,
    shuffle=True,
    num_workers=0
) 

test = torchvision.datasets.ImageFolder(
    root = test_path+'jpg/jpg/',
    transform = transform
)
test_loader = torch.utils.data.DataLoader(
    test, 
    batch_size= 32,
    shuffle=True,
    num_workers=0
)

# %%
BATCH_SIZE = 256

train_iterator = data.DataLoader(train,
                                 shuffle=True,
                                 batch_size=BATCH_SIZE)

#valid_iterator = data.DataLoader(valid_data,
#                                 batch_size=BATCH_SIZE)

test_iterator = data.DataLoader(test,
                                batch_size=BATCH_SIZE)

# %%
fig, axes = plt.subplots(4,4,figsize= (15,15))
for i in range(16):
    img = train[i][0].numpy().transpose(1, 2, 0)
    img = np.clip((std * img) + mean, 0, 1)
    axes.flat[i].imshow(img)
    axes.flat[i].set_title(str(train[i][1]))
# Follow aspect ratio of either 1:1 or 1.68:1 (8.5, 4.75/5)
fig.savefig('/content/Alexnet_analysis/train_image_transformations.jpg', dpi=300, bbox_inches='tight')  
fig.savefig('/content/Alexnet_analysis/train_image_transformations.pdf', dpi=300, bbox_inches='tight')  
plt.show()

# %%
class AlexNet(nn.Module):
    def __init__(self, output_dim):
        super().__init__()

        self.features = nn.Sequential(
            nn.Conv2d(3, 64, 3, 2, 1),  # in_channels, out_channels, kernel_size, stride, padding
            nn.MaxPool2d(2),  # kernel_size
            nn.ReLU(inplace=True),
            nn.Conv2d(64, 192, 3, padding=1),
            nn.MaxPool2d(2),
            nn.ReLU(inplace=True),
            nn.Conv2d(192, 384, 3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(384, 256, 3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(256, 256, 3, padding=1),
            nn.MaxPool2d(2),
            nn.ReLU(inplace=True)
        )

        self.classifier = nn.Sequential(
            nn.Dropout(0.5),
            nn.Linear(256 * 2 * 2, 4096),
            nn.ReLU(inplace=True),
            nn.Dropout(0.5),
            nn.Linear(4096, 4096),
            nn.ReLU(inplace=True),
            nn.Linear(4096, output_dim),
        )

    def forward(self, x):
        x = self.features(x)
        h = x.view(x.shape[0], -1)
        x = self.classifier(h)
        return x, h

# %%
OUTPUT_DIM = 15

model = AlexNet(OUTPUT_DIM)

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)


print(f'The model has {count_parameters(model):,} trainable parameters')
# Out:
# The model has 23,292,751 trainable parameters

# %%
def initialize_parameters(m):
    if isinstance(m, nn.Conv2d):
        nn.init.kaiming_normal_(m.weight.data, nonlinearity='relu')
        nn.init.constant_(m.bias.data, 0)
    elif isinstance(m, nn.Linear):
        nn.init.xavier_normal_(m.weight.data, gain=nn.init.calculate_gain('relu'))
        nn.init.constant_(m.bias.data, 0)

# %%
model.apply(initialize_parameters)
# Out:
# AlexNet(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(64, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): ReLU(inplace=True)
#     (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace=True)
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (12): ReLU(inplace=True)
#   )
#   (classifier): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
#     (1): Linear(in_features=1024, out_features=4096, bias=True)
#     (2): ReLU(inplace=True)
#     (3): Dropout(p=0.5, inplace=False)
#     (4): Linear(in_features=4096, out_features=4096, bias=True)
#     (5): ReLU(inplace=True)
#     (6): Linear(in_features=4096, out_features=15, bias=True)
#   )
# )

# %%
class LRFinder:
    def __init__(self, model, optimizer, criterion, device):

        self.optimizer = optimizer
        self.model = model
        self.criterion = criterion
        self.device = device

        torch.save(model.state_dict(), 'init_params.pt')

    def range_test(self, iterator, end_lr=10, num_iter=100,
                   smooth_f=0.05, diverge_th=5):

        lrs = []
        losses = []
        best_loss = float('inf')

        lr_scheduler = ExponentialLR(self.optimizer, end_lr, num_iter)

        iterator = IteratorWrapper(iterator)

        for iteration in range(num_iter):

            loss = self._train_batch(iterator)

            lrs.append(lr_scheduler.get_last_lr()[0])

            # update lr
            lr_scheduler.step()

            if iteration > 0:
                loss = smooth_f * loss + (1 - smooth_f) * losses[-1]

            if loss < best_loss:
                best_loss = loss

            losses.append(loss)

            if loss > diverge_th * best_loss:
                print("Stopping early, the loss has diverged")
                break

        # reset model to initial parameters
        model.load_state_dict(torch.load('init_params.pt'))

        return lrs, losses

    def _train_batch(self, iterator):

        self.model.train()

        self.optimizer.zero_grad()

        x, y = iterator.get_batch()

        x = x.to(self.device)
        y = y.to(self.device)

        y_pred, _ = self.model(x)

        loss = self.criterion(y_pred, y)

        loss.backward()

        self.optimizer.step()

        return loss.item()


class ExponentialLR(_LRScheduler):
    def __init__(self, optimizer, end_lr, num_iter, last_epoch=-1):
        self.end_lr = end_lr
        self.num_iter = num_iter
        super(ExponentialLR, self).__init__(optimizer, last_epoch)

    def get_lr(self):
        curr_iter = self.last_epoch
        r = curr_iter / self.num_iter
        return [base_lr * (self.end_lr / base_lr) ** r
                for base_lr in self.base_lrs]


class IteratorWrapper:
    def __init__(self, iterator):
        self.iterator = iterator
        self._iterator = iter(iterator)

    def __next__(self):
        try:
            inputs, labels = next(self._iterator)
        except StopIteration:
            self._iterator = iter(self.iterator)
            inputs, labels, *_ = next(self._iterator)

        return inputs, labels

    def get_batch(self):
        return next(self)

# %%
START_LR = 1e-7

optimizer = optim.Adam(model.parameters(), lr=START_LR)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

criterion = nn.CrossEntropyLoss()

model = model.to(device)
criterion = criterion.to(device)

# %%
END_LR = 10
NUM_ITER = 100

lr_finder = LRFinder(model, optimizer, criterion, device)
lrs, losses = lr_finder.range_test(train_iterator, END_LR, NUM_ITER)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-26-937508221c7d> in <module>()
#       3
#       4 lr_finder = LRFinder(model, optimizer, criterion, device)
# ----> 5 lrs, losses = lr_finder.range_test(train_iterator, END_LR, NUM_ITER)
#
# <ipython-input-20-55df6c3aa491> in range_test(self, iterator, end_lr, num_iter, smooth_f, diverge_th)
#      22         for iteration in range(num_iter):
#      23
# ---> 24             loss = self._train_batch(iterator)
#      25
#      26             lrs.append(lr_scheduler.get_last_lr()[0])
#
# <ipython-input-20-55df6c3aa491> in _train_batch(self, iterator)
#      57         y = y.to(self.device)
#      58
# ---> 59         y_pred, _ = self.model(x)
#      60
#      61         loss = self.criterion(y_pred, y)
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# <ipython-input-15-cb1ea0804101> in forward(self, x)
#      32         x = self.features(x)
#      33         h = x.view(x.shape[0], -1)
# ---> 34         x = self.classifier(h)
#      35         return x, h
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/container.py in forward(self, input)
#     137     def forward(self, input):
#     138         for module in self:
# --> 139             input = module(input)
#     140         return input
#     141
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/linear.py in forward(self, input)
#     112
#     113     def forward(self, input: Tensor) -> Tensor:
# --> 114         return F.linear(input, self.weight, self.bias)
#     115
#     116     def extra_repr(self) -> str:
#
# RuntimeError: mat1 and mat2 shapes cannot be multiplied (86x50176 and 1024x4096)

# %%
def plot_lr_finder(lrs, losses, skip_start=5, skip_end=5):

    if skip_end == 0:
        lrs = lrs[skip_start:]
        losses = losses[skip_start:]
    else:
        lrs = lrs[skip_start:-skip_end]
        losses = losses[skip_start:-skip_end]

    fig = plt.figure(figsize=(16, 8))
    ax = fig.add_subplot(1, 1, 1)
    ax.plot(lrs, losses)
    ax.set_xscale('log')
    ax.set_xlabel('Learning rate')
    ax.set_ylabel('Loss')
    ax.grid(True, 'both', 'x')
    plt.show()

# %%
plot_lr_finder(lrs, losses)

# %%
FOUND_LR = 1e-3

optimizer = optim.Adam(model.parameters(), lr=FOUND_LR)

# %%
def calculate_accuracy(y_pred, y):
    top_pred = y_pred.argmax(1, keepdim=True)
    correct = top_pred.eq(y.view_as(top_pred)).sum()
    acc = correct.float() / y.shape[0]
    return acc

# %%
def train(model, iterator, optimizer, criterion, device):

    epoch_loss = 0
    epoch_acc = 0

    model.train()

    for (x, y) in tqdm(iterator, desc="Training", leave=False):

        x = x.to(device)
        y = y.to(device)

        optimizer.zero_grad()

        y_pred, _ = model(x)

        loss = criterion(y_pred, y)

        acc = calculate_accuracy(y_pred, y)

        loss.backward()

        optimizer.step()

        epoch_loss += loss.item()
        epoch_acc += acc.item()

    return epoch_loss / len(iterator), epoch_acc / len(iterator)

# %%
def evaluate(model, iterator, criterion, device):

    epoch_loss = 0
    epoch_acc = 0

    model.eval()

    with torch.no_grad():

        for (x, y) in tqdm(iterator, desc="Evaluating", leave=False):

            x = x.to(device)
            y = y.to(device)

            y_pred, _ = model(x)

            loss = criterion(y_pred, y)

            acc = calculate_accuracy(y_pred, y)

            epoch_loss += loss.item()
            epoch_acc += acc.item()

    return epoch_loss / len(iterator), epoch_acc / len(iterator)

# %%
def epoch_time(start_time, end_time):
    elapsed_time = end_time - start_time
    elapsed_mins = int(elapsed_time / 60)
    elapsed_secs = int(elapsed_time - (elapsed_mins * 60))
    return elapsed_mins, elapsed_secs

# %%
EPOCHS = 50

best_valid_loss = float('inf')

for epoch in trange(EPOCHS, desc="Epochs"):

    start_time = time.monotonic()

    train_loss, train_acc = train(model, train_iterator, optimizer, criterion, device)
    valid_loss, valid_acc = evaluate(model, valid_iterator, criterion, device)

    if valid_loss < best_valid_loss:
        best_valid_loss = valid_loss
        torch.save(model.state_dict(), 'tut3-model.pt')

    end_time = time.monotonic()

    epoch_mins, epoch_secs = epoch_time(start_time, end_time)

    print(f'Epoch: {epoch+1:02} | Epoch Time: {epoch_mins}m {epoch_secs}s')
    print(f'\tTrain Loss: {train_loss:.3f} | Train Acc: {train_acc*100:.2f}%')
    print(f'\t Val. Loss: {valid_loss:.3f} |  Val. Acc: {valid_acc*100:.2f}%')

# %%
model.load_state_dict(torch.load('tut3-model.pt'))

test_loss, test_acc = evaluate(model, test_iterator, criterion, device)

print(f'Test Loss: {test_loss:.3f} | Test Acc: {test_acc*100:.2f}%')

# %%
def get_predictions(model, iterator, device):

    model.eval()

    images = []
    labels = []
    probs = []

    with torch.no_grad():

        for (x, y) in iterator:

            x = x.to(device)

            y_pred, _ = model(x)

            y_prob = F.softmax(y_pred, dim=-1)

            images.append(x.cpu())
            labels.append(y.cpu())
            probs.append(y_prob.cpu())

    images = torch.cat(images, dim=0)
    labels = torch.cat(labels, dim=0)
    probs = torch.cat(probs, dim=0)

    return images, labels, probs

images, labels, probs = get_predictions(model, test_iterator, device)

# %%
pred_labels = torch.argmax(probs, 1)

def plot_confusion_matrix(labels, pred_labels, classes):

    fig = plt.figure(figsize=(10, 10))
    ax = fig.add_subplot(1, 1, 1)
    cm = confusion_matrix(labels, pred_labels)
    cm = ConfusionMatrixDisplay(cm, display_labels=classes)
    cm.plot(values_format='d', cmap='Blues', ax=ax)
    plt.xticks(rotation=20)

plot_confusion_matrix(labels, pred_labels, classes)

# %%
alexnet = models.alexnet(pretrained=True)

normalize = transforms.Normalize(mean=[0.5683, 0.5578, 0.5178],
                                 std=[0.2378, 0.2437, 0.2670])
# Out:
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:209: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   f"The parameter '{pretrained_param}' is deprecated since 0.13 and will be removed in 0.15, "
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
